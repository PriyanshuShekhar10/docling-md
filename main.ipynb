# %%
# !pip install docling transformers

# %%
import os
os.environ["HF_HUB_DISABLE_SYMLINKS"] = "1"

# %%
from docling.document_converter import DocumentConverter
from pathlib import Path

def pdf_to_markdown(pdf_path: str, output_path: str):
    # Initialize Docling converter
    converter = DocumentConverter()
    
    # Convert the PDF
    result = converter.convert(pdf_path)
    
    # Extract Markdown
    markdown = result.document.export_to_markdown()
    
    # Save to file
    Path(output_path).write_text(markdown, encoding="utf-8")
    print(f"✅ Converted {pdf_path} -> {output_path}")

if __name__ == "__main__":
    pdf_to_markdown("sample.pdf", "output.md")
# Out:
# 2025-09-18 15:11:10,110 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-09-18 15:11:18,532 - INFO - Going to convert document batch...
# 2025-09-18 15:11:18,533 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e647edf348883bed75367b22fbe60347
# 2025-09-18 15:11:18,534 - INFO - Accelerator device: 'cpu'
# 2025-09-18 15:11:20,228 - INFO - Accelerator device: 'cpu'
# d:\docling\venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Priyanshu\.cache\huggingface\hub\models--ds4sd--docling-models. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# 2025-09-18 15:11:36,306 - INFO - Accelerator device: 'cpu'
# 2025-09-18 15:11:36,669 - INFO - Processing document sample.pdf
# d:\docling\venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-09-18 15:13:16,425 - INFO - Finished converting document sample.pdf in 126.33 sec.
# ✅ Converted sample.pdf -> output.md

# %%
import torch

# %%
import os
from pathlib import Path
import torch

from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions
from docling.datamodel.base_models import InputFormat

# For Windows symlink issue
os.environ["HF_HUB_DISABLE_SYMLINKS"] = "1"


def pdf_to_markdown(pdf_path: str, output_path: str):
    # pick device
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print(f"Using device: {device}")

    # pipeline options: enable OCR etc if needed
    opts = PdfPipelineOptions()
    # use OCR only if needed
    opts.do_ocr = True  # or False if your PDF already has embedded text
    # tell it to use GPU
    opts.accelerator_options.device = device

    # Create converter
    converter = DocumentConverter(
        format_options={
            InputFormat.PDF: PdfFormatOption(pipeline_options=opts)
        }
    )

    # Convert
    result = converter.convert(pdf_path)

    md = result.document.export_to_markdown()

    Path(output_path).write_text(md, encoding="utf-8")
    print(f"✔️ Done: {pdf_path} -> {output_path}")


if __name__ == "__main__":
    pdf_to_markdown("sample.pdf", "output.md")
# Out:
# 2025-09-18 15:16:21,602 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# Using device: cpu
# 2025-09-18 15:16:30,506 - INFO - Going to convert document batch...
# 2025-09-18 15:16:30,507 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 44750bf936770741b0779c5d88b7b475
# 2025-09-18 15:16:30,508 - INFO - Accelerator device: 'cpu'
# 2025-09-18 15:16:32,220 - INFO - Accelerator device: 'cpu'
# 2025-09-18 15:16:33,499 - INFO - Accelerator device: 'cpu'
# 2025-09-18 15:16:34,047 - INFO - Processing document sample.pdf
# d:\docling\venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 42
#      38     print(f"✔️ Done: {pdf_path} -> {output_path}")
#      41 if __name__ == "__main__":
# ---> 42     pdf_to_markdown("sample.pdf", "output.md")
#
# Cell In[9], line 33, in pdf_to_markdown(pdf_path, output_path)
#      26 converter = DocumentConverter(
#      27     format_options={
#      28         InputFormat.PDF: PdfFormatOption(pipeline_options=opts)
#      29     }
#      30 )
#      32 # Convert
# ---> 33 result = converter.convert(pdf_path)
#      35 md = result.document.export_to_markdown()
#      37 Path(output_path).write_text(md, encoding="utf-8")
#
# File d:\docling\venv\Lib\site-packages\pydantic\_internal\_validate_call.py:39, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      37 @functools.wraps(wrapped)
#      38 def wrapper_function(*args, **kwargs):
# ---> 39     return wrapper(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\pydantic\_internal\_validate_call.py:136, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     133 if not self.__pydantic_complete__:
#     134     self._create_validators()
# --> 136 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     137 if self.__return_pydantic_validator__:
#     138     return self.__return_pydantic_validator__(res)
#
# File d:\docling\venv\Lib\site-packages\docling\document_converter.py:241, in DocumentConverter.convert(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     223 @validate_call(config=ConfigDict(strict=True))
#     224 def convert(
#     225     self,
#    (...)    231     page_range: PageRange = DEFAULT_PAGE_RANGE,
#     232 ) -> ConversionResult:
#     233     all_res = self.convert_all(
#     234         source=[source],
#     235         raises_on_error=raises_on_error,
#    (...)    239         page_range=page_range,
#     240     )
# --> 241     return next(all_res)
#
# File d:\docling\venv\Lib\site-packages\docling\document_converter.py:264, in DocumentConverter.convert_all(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     261 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
#     263 had_result = False
# --> 264 for conv_res in conv_res_iter:
#     265     had_result = True
#     266     if raises_on_error and conv_res.status not in {
#     267         ConversionStatus.SUCCESS,
#     268         ConversionStatus.PARTIAL_SUCCESS,
#     269     }:
#
# File d:\docling\venv\Lib\site-packages\docling\document_converter.py:336, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     334             yield item
#     335 else:
# --> 336     for item in map(
#     337         process_func,
#     338         input_batch,
#     339     ):
#     340         elapsed = time.monotonic() - start_time
#     341         start_time = time.monotonic()
#
# File d:\docling\venv\Lib\site-packages\docling\document_converter.py:383, in DocumentConverter._process_document(self, in_doc, raises_on_error)
#     379 valid = (
#     380     self.allowed_formats is not None and in_doc.format in self.allowed_formats
#     381 )
#     382 if valid:
# --> 383     conv_res = self._execute_pipeline(in_doc, raises_on_error=raises_on_error)
#     384 else:
#     385     error_message = f"File format not allowed: {in_doc.file}"
#
# File d:\docling\venv\Lib\site-packages\docling\document_converter.py:406, in DocumentConverter._execute_pipeline(self, in_doc, raises_on_error)
#     404 pipeline = self._get_pipeline(in_doc.format)
#     405 if pipeline is not None:
# --> 406     conv_res = pipeline.execute(in_doc, raises_on_error=raises_on_error)
#     407 else:
#     408     if raises_on_error:
#
# File d:\docling\venv\Lib\site-packages\docling\pipeline\base_pipeline.py:72, in BasePipeline.execute(self, in_doc, raises_on_error)
#      66 try:
#      67     with TimeRecorder(
#      68         conv_res, "pipeline_total", scope=ProfilingScope.DOCUMENT
#      69     ):
#      70         # These steps are building and assembling the structure of the
#      71         # output DoclingDocument.
# ---> 72         conv_res = self._build_document(conv_res)
#      73         conv_res = self._assemble_document(conv_res)
#      74         # From this stage, all operations should rely only on conv_res.output
#
# File d:\docling\venv\Lib\site-packages\docling\pipeline\base_pipeline.py:230, in PaginatedPipeline._build_document(self, conv_res)
#     227 # 2. Run pipeline stages
#     228 pipeline_pages = self._apply_on_pages(conv_res, init_pages)
# --> 230 for p in pipeline_pages:  # Must exhaust!
#     231     # Cleanup cached images
#     232     if not self.keep_images:
#     233         p._image_cache = {}
#
# File d:\docling\venv\Lib\site-packages\docling\pipeline\base_pipeline.py:195, in PaginatedPipeline._apply_on_pages(self, conv_res, page_batch)
#     192 for model in self.build_pipe:
#     193     page_batch = model(conv_res, page_batch)
# --> 195 yield from page_batch
#
# File d:\docling\venv\Lib\site-packages\docling\models\page_assemble_model.py:70, in PageAssembleModel.__call__(self, conv_res, page_batch)
#      67 def __call__(
#      68     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#      69 ) -> Iterable[Page]:
# ---> 70     for page in page_batch:
#      71         assert page._backend is not None
#      72         if not page._backend.is_valid():
#
# File d:\docling\venv\Lib\site-packages\docling\models\table_structure_model.py:177, in TableStructureModel.__call__(self, conv_res, page_batch)
#     174     yield from page_batch
#     175     return
# --> 177 for page in page_batch:
#     178     assert page._backend is not None
#     179     if not page._backend.is_valid():
#
# File d:\docling\venv\Lib\site-packages\docling\models\layout_model.py:174, in LayoutModel.__call__(self, conv_res, page_batch)
#     172 if valid_page_images:
#     173     with TimeRecorder(conv_res, "layout"):
# --> 174         batch_predictions = self.layout_predictor.predict_batch(  # type: ignore[attr-defined]
#     175             valid_page_images
#     176         )
#     178 # Process each page with its predictions
#     179 valid_page_idx = 0
#
# File d:\docling\venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\docling_ibm_models\layoutmodel\layout_predictor.py:222, in LayoutPredictor.predict_batch(self, images)
#     218 # Process all images in a single batch
#     219 inputs = self._image_processor(images=pil_images, return_tensors="pt").to(
#     220     self._device
#     221 )
# --> 222 outputs = self._model(**inputs)
#     224 # Post-process all results at once
#     225 results_list: List[Dict[str, Tensor]] = (
#     226     self._image_processor.post_process_object_detection(
#     227         outputs,
#    (...)    230     )
#     231 )
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr_v2\modeling_rt_detr_v2.py:1920, in RTDetrV2ForObjectDetection.forward(self, pixel_values, pixel_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1915 output_hidden_states = (
#    1916     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1917 )
#    1918 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1920 outputs = self.model(
#    1921     pixel_values,
#    1922     pixel_mask=pixel_mask,
#    1923     encoder_outputs=encoder_outputs,
#    1924     inputs_embeds=inputs_embeds,
#    1925     decoder_inputs_embeds=decoder_inputs_embeds,
#    1926     labels=labels,
#    1927     output_attentions=output_attentions,
#    1928     output_hidden_states=output_hidden_states,
#    1929     return_dict=return_dict,
#    1930 )
#    1932 denoising_meta_values = (
#    1933     outputs.denoising_meta_values if return_dict else outputs[-1] if self.training else None
#    1934 )
#    1936 outputs_class = outputs.intermediate_logits if return_dict else outputs[2]
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr_v2\modeling_rt_detr_v2.py:1539, in RTDetrV2Model.forward(self, pixel_values, pixel_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1536 if pixel_mask is None:
#    1537     pixel_mask = torch.ones(((batch_size, height, width)), device=device)
# -> 1539 features = self.backbone(pixel_values, pixel_mask)
#    1541 proj_feats = [self.encoder_input_proj[level](source) for level, (source, mask) in enumerate(features)]
#    1543 if encoder_outputs is None:
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr_v2\modeling_rt_detr_v2.py:865, in RTDetrV2ConvEncoder.forward(self, pixel_values, pixel_mask)
#     863 def forward(self, pixel_values: torch.Tensor, pixel_mask: torch.Tensor):
#     864     # send pixel_values through the model to get list of feature maps
# --> 865     features = self.model(pixel_values).feature_maps
#     867     out = []
#     868     for feature_map in features:
#     869         # downsample pixel_mask to match shape of corresponding feature_map
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr\modeling_rt_detr_resnet.py:374, in RTDetrResNetBackbone.forward(self, pixel_values, output_hidden_states, return_dict)
#     368 output_hidden_states = (
#     369     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#     370 )
#     372 embedding_output = self.embedder(pixel_values)
# --> 374 outputs = self.encoder(embedding_output, output_hidden_states=True, return_dict=True)
#     376 hidden_states = outputs.hidden_states
#     378 feature_maps = ()
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr\modeling_rt_detr_resnet.py:283, in RTDetrResNetEncoder.forward(self, hidden_state, output_hidden_states, return_dict)
#     280     if output_hidden_states:
#     281         hidden_states = hidden_states + (hidden_state,)
# --> 283     hidden_state = stage_module(hidden_state)
#     285 if output_hidden_states:
#     286     hidden_states = hidden_states + (hidden_state,)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr\modeling_rt_detr_resnet.py:251, in RTDetrResNetStage.forward(self, input)
#     249 hidden_state = input
#     250 for layer in self.layers:
# --> 251     hidden_state = layer(hidden_state)
#     252 return hidden_state
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr\modeling_rt_detr_resnet.py:211, in RTDetrResNetBottleNeckLayer.forward(self, hidden_state)
#     209 def forward(self, hidden_state):
#     210     residual = hidden_state
# --> 211     hidden_state = self.layer(hidden_state)
#     212     residual = self.shortcut(residual)
#     213     hidden_state += residual
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\transformers\models\rt_detr\modeling_rt_detr_resnet.py:49, in RTDetrResNetConvLayer.forward(self, input)
#      48 def forward(self, input: Tensor) -> Tensor:
# ---> 49     hidden_state = self.convolution(input)
#      50     hidden_state = self.normalization(hidden_state)
#      51     hidden_state = self.activation(hidden_state)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File d:\docling\venv\Lib\site-packages\torch\nn\modules\conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:
